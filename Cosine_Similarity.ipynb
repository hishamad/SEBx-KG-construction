# %% [markdown]
# # Cosine Similarity as a consensus metric
#
# Cosine similarity measures how close two vectors are in a vector space. The idea is to represetn the triplets we have in the vector space and check whether the different models have similar output.
#
# For the following discussion, consider a document that contains three pieces of knowledge that can be represented as triplets A, B, and C. We will use triplets D, E, F to represent hallucinations.
#
# ## Issues:
# - Entities often are names.
# - The same entity can be extracted with different names.
# - A triplet has 3 components, we can't take its cosine similarity directly.
# - Not all models extract the same number of triplets. Some models might exctract the same piece of information multiple times, while others could miss it entirely.
# - We don't know which of the triplets exctracted match onto which piece of knowledge.

# %%
# !wget https://github.com/hishamad/SEBx-KG-construction/raw/main/output/gpt_triplets.json
# !wget https://github.com/hishamad/SEBx-KG-construction/raw/main/output/llama_triplets.json
# !wget https://github.com/hishamad/SEBx-KG-construction/raw/main/output/mixtral_triplets.json
# Out:
# --2024-11-01 12:25:19--  https://github.com/hishamad/SEBx-KG-construction/raw/main/output/gpt_triplets.json
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/hishamad/SEBx-KG-construction/main/output/gpt_triplets.json [following]
# --2024-11-01 12:25:19--  https://raw.githubusercontent.com/hishamad/SEBx-KG-construction/main/output/gpt_triplets.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 155017 (151K) [text/plain]
# Saving to: ‘gpt_triplets.json.1’
#
# gpt_triplets.json.1 100%[===================>] 151.38K  --.-KB/s    in 0.02s
#
# 2024-11-01 12:25:19 (7.17 MB/s) - ‘gpt_triplets.json.1’ saved [155017/155017]
#
# --2024-11-01 12:25:19--  https://github.com/hishamad/SEBx-KG-construction/raw/main/output/llama_triplets.json
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/hishamad/SEBx-KG-construction/main/output/llama_triplets.json [following]
# --2024-11-01 12:25:20--  https://raw.githubusercontent.com/hishamad/SEBx-KG-construction/main/output/llama_triplets.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 200125 (195K) [text/plain]
# Saving to: ‘llama_triplets.json.1’
#
# llama_triplets.json 100%[===================>] 195.43K  --.-KB/s    in 0.02s
#
# 2024-11-01 12:25:20 (9.07 MB/s) - ‘llama_triplets.json.1’ saved [200125/200125]
#
# --2024-11-01 12:25:20--  https://github.com/hishamad/SEBx-KG-construction/raw/main/output/mixtral_triplets.json
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/hishamad/SEBx-KG-construction/main/output/mixtral_triplets.json [following]
# --2024-11-01 12:25:20--  https://raw.githubusercontent.com/hishamad/SEBx-KG-construction/main/output/mixtral_triplets.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 277899 (271K) [text/plain]
# Saving to: ‘mixtral_triplets.json.1’
#
# mixtral_triplets.js 100%[===================>] 271.39K  --.-KB/s    in 0.02s
#
# 2024-11-01 12:25:20 (12.2 MB/s) - ‘mixtral_triplets.json.1’ saved [277899/277899]

# %%
# !pip install gensim
from gensim.models import KeyedVectors
import numpy as np
import json
import numpy as np
import math
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (7.0.5)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim) (1.16.0)

# %%
with open('gpt_triplets.json', 'r') as f:
    gpt_data = json.load(f)

with open('llama_triplets.json', 'r') as f:
    llama_data = json.load(f)

with open('mixtral_triplets.json', 'r') as f:
    mixtral_data = json.load(f)


print (len(gpt_data))
print (len(llama_data))
print (len(mixtral_data))

print (gpt_data[0])
print (llama_data[0])
print (mixtral_data[0])
# Out:
# 301
# 300
# 301
# {'subject': ['CapGen Capital Group VI LP', 'CapGen Capital Group VI LP'], 'subject_type': ['ORG', 'ORG'], 'relationship': ['Invests_In', 'Has'], 'object': ['Union Bankshares Corp', 'Stake', 'Union Bankshares Corp'], 'object_type': ['COMP', 'FIN_INSTRUMENT']}
# {'subject': ['CAPGEN CAPITAL GROUP VI LP', 'CAPGEN CAPITAL GROUP VI LP', 'CAPGEN CAPITAL GROUP', 'Union Bankshares Corp'], 'subject_type': ['ORG', 'ORG', 'ORG', 'COMP'], 'relationship': ['Has', 'Announce', 'Participates_In', 'Operate_In'], 'object': ['Union Bankshares Corp', '7.3 Pct Stake in Union Bankshares Corp', "Union Bankshares Corp's Management", 'Union Bankshares Corp'], 'object_type': ['COMP', 'FIN_INSTRUMENT', 'ORG', 'COMP']}
# {'subject': ['Union Bankshares Corp', 'CAPGEN Capital Group VI LP', 'CAPGEN Capital Group VI LP', 'CAPGEN Capital Group VI LP', 'CAPGEN Capital Group VI LP', 'CAPGEN Capital Group VI LP', 'CAPGEN Capital Group VI LP'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP', 'COMP', 'COMP', 'COMP'], 'relationship': ['Has', 'Reports', 'Has', 'Intend', 'Control', 'Discuss', 'Relate_To'], 'object': ['7.3 PCT Stake', '7.3 PCT Stake', 'Discussions', 'Discussions', 'Union Bankshares Corp', 'Financing & Strategic Alternatives', "Union Bankshares' Management"], 'object_type': ['FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'CONCEPT', 'CONCEPT', 'COMP', 'CONCEPT', 'ORG']}

# %% [markdown]
# # The word2vec model
# The pre-trained Google News word2vec model contains **3 million word vectors**, each with **300 dimensions**. This model was trained on approximately 100 billion words from Google News.

# %%
w2v_model = KeyedVectors.load_word2vec_format('/content/drive/MyDrive/GoogleNews-vectors-negative300.bin.gz', binary=True)

# %%
def prep_word_vec(model, word):
  words = word.lower().split()
  output_vector  = np.zeros(300)
  word_count = 0
  for w in words:
    if w in model:
      output_vector += model[w]
      word_count += 1

  if word_count == 0:
    return np.zeros(300)

  return output_vector/word_count


def process_triplet(model, subject, relation, obj):
  subject_vector = prep_word_vec(model, subject)
  relation_vector = prep_word_vec(model, relation)
  object_vector = prep_word_vec(model, obj)

  return subject_vector, relation_vector, object_vector

# %%
from multiprocessing import process

avg_similarity = 0


for i in range(300):
  total_pairs = 0
  total_similarity_count = 0
  cos_score = 0

  skip_gpt = False
  skip_llama = False
  skip_mixtral = False

  gpt_triplets = gpt_data[i]
  llama_triplets = llama_data[i]
  mixtral_triplets = mixtral_data[i]

  gpt_complete_triplets = min(len(gpt_triplets['subject']), len(gpt_triplets['relationship']), len(gpt_triplets['object']))
  llama_complete_triplets = min(len(llama_triplets['subject']), len(llama_triplets['relationship']), len(llama_triplets['object']))
  mixtral_complete_triplets = min(len(mixtral_triplets['subject']), len(mixtral_triplets['relationship']), len(mixtral_triplets['object']))


  print (gpt_triplets)
  print (llama_triplets)
  print (mixtral_triplets)

  if gpt_complete_triplets == 0:
    skip_gpt = True

  if llama_complete_triplets == 0:
    skip_llama = True

  if mixtral_complete_triplets == 0:
    skip_mixtral = True


  if not skip_gpt:
    gpt_subject, gpt_relation, gpt_obj  = gpt_triplets['subject'], gpt_triplets['relationship'], gpt_triplets['object']

  if not skip_llama:
    llama_subject, llama_relation, llama_obj  = llama_triplets['subject'], llama_triplets['relationship'], llama_triplets['object']

  if not skip_mixtral:
    mixtral_subject, mixtral_relation, mixtral_obj  = mixtral_triplets['subject'], mixtral_triplets['relationship'], mixtral_triplets['object']

  if not skip_gpt:
    gpt_triplet_vectors = []
    for j in range(gpt_complete_triplets):
      subject_vector, relationship_vector, object_vector = process_triplet(w2v_model, gpt_subject[j], gpt_relation[j], gpt_obj[j])
      gpt_triplet_vectors.append((subject_vector + relationship_vector + object_vector)/3)

  if not skip_llama:
    llama_triplet_vectors = []
    for j in range(llama_complete_triplets):
      subject_vector, relationship_vector, object_vector = process_triplet(w2v_model, llama_subject[j], llama_relation[j], llama_obj[j])
      llama_triplet_vectors.append((subject_vector + relationship_vector + object_vector)/3)

  if not skip_mixtral:
    mixtral_triplet_vectors = []
    for j in range(mixtral_complete_triplets):
      subject_vector, relationship_vector, object_vector = process_triplet(w2v_model, mixtral_subject[j], mixtral_relation[j], mixtral_obj[j])
      mixtral_triplet_vectors.append((subject_vector + relationship_vector + object_vector)/3)

  total_similarity_count = 0


  if not skip_gpt and not skip_llama:
    gpt_llama_vector_pair_similairty = {}
    sims = cosine_similarity(gpt_triplet_vectors, llama_triplet_vectors)
    for j in range(gpt_complete_triplets):
      for q in range(llama_complete_triplets):
        gpt_llama_vector_pair_similairty[(j, q)] = sims[j][q]
        total_similarity_count += sims[j][q]
    total_pairs += gpt_complete_triplets * llama_complete_triplets


  if not skip_gpt and not skip_mixtral:
    gpt_mixtral_vector_pair_similairty = {}
    sims = cosine_similarity(gpt_triplet_vectors, mixtral_triplet_vectors)
    for j in range(gpt_complete_triplets):
      for q in range(mixtral_complete_triplets):
        gpt_mixtral_vector_pair_similairty[(j, q)] = sims[j][q]
        total_similarity_count += sims[j][q]
    total_pairs += gpt_complete_triplets * mixtral_complete_triplets

  if not skip_llama and not skip_mixtral:
    llama_mixtral_vector_pair_similairty = {}
    sims = cosine_similarity(llama_triplet_vectors, mixtral_triplet_vectors)
    for j in range(llama_complete_triplets):
      for q in range(mixtral_complete_triplets):
        llama_mixtral_vector_pair_similairty[(j, q)] = sims[j][q]
        total_similarity_count += sims[j][q]
    total_pairs += llama_complete_triplets * mixtral_complete_triplets


  print("Doc #"+str(i)+": ")
  print ("Total pairs: ", total_pairs)

  total_similarity_count = math.trunc(total_similarity_count*100)/100
  print ("Total similarity count: ",total_similarity_count)

  cos_score = (total_similarity_count/total_pairs) * 100
  avg_similarity += cos_score

  cos_score = math.trunc(cos_score*100)/100
  print ("Cosine similarity 'score': ", cos_score)
  print ("----------------------------------------------------")


print("Average similarity: ", avg_similarity/300)
# Out:
# {'subject': ['CapGen Capital Group VI LP', 'CapGen Capital Group VI LP'], 'subject_type': ['ORG', 'ORG'], 'relationship': ['Invests_In', 'Has'], 'object': ['Union Bankshares Corp', 'Stake', 'Union Bankshares Corp'], 'object_type': ['COMP', 'FIN_INSTRUMENT']}
# {'subject': ['CAPGEN CAPITAL GROUP VI LP', 'CAPGEN CAPITAL GROUP VI LP', 'CAPGEN CAPITAL GROUP', 'Union Bankshares Corp'], 'subject_type': ['ORG', 'ORG', 'ORG', 'COMP'], 'relationship': ['Has', 'Announce', 'Participates_In', 'Operate_In'], 'object': ['Union Bankshares Corp', '7.3 Pct Stake in Union Bankshares Corp', "Union Bankshares Corp's Management", 'Union Bankshares Corp'], 'object_type': ['COMP', 'FIN_INSTRUMENT', 'ORG', 'COMP']}
# {'subject': ['Union Bankshares Corp', 'CAPGEN Capital Group VI LP', 'CAPGEN Capital Group VI LP', 'CAPGEN Capital Group VI LP', 'CAPGEN Capital Group VI LP', 'CAPGEN Capital Group VI LP', 'CAPGEN Capital Group VI LP'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP', 'COMP', 'COMP', 'COMP'], 'relationship': ['Has', 'Reports', 'Has', 'Intend', 'Control', 'Discuss', 'Relate_To'], 'object': ['7.3 PCT Stake', '7.3 PCT Stake', 'Discussions', 'Discussions', 'Union Bankshares Corp', 'Financing & Strategic Alternatives', "Union Bankshares' Management"], 'object_type': ['FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'CONCEPT', 'CONCEPT', 'COMP', 'CONCEPT', 'ORG']}
# Doc #0:
# Total pairs:  50
# Total similarity count:  25.65
# Cosine similarity 'score':  51.3
# ----------------------------------------------------
# {'subject': ['Canada Pension Plan Investment Board', 'Canada Pension Plan Investment Board', 'Asian Development Bank'], 'subject_type': ['ORG', 'ORG', 'ORGREG'], 'relationship': ['Invests_In', 'Invests_In', 'Invests_In'], 'object': ['Renew Power Ventures', 'Renew Power', 'Renew Power'], 'object_type': ['COMP', 'COMP', 'COMP']}
# {'subject': ['Canada Pension Plan Investment Board', 'Canada Pension Plan Investment Board', 'Asian Development Bank'], 'subject_type': ['ORG', 'ORG', 'ORGGOV'], 'relationship': ['Invests_In', 'Acquiring', 'Control'], 'object': ['Renew Power Ventures PVT. LTD.', 'Renew Power', 'Renew Power Ventures PVT. LTD.'], 'object_type': ['ORG', 'ORG', 'ORG']}
# {'subject': ['Canada Pension Plan Investment Board', 'Canada Pension Plan Investment Board', 'Canada Pension Plan Investment Board'], 'subject_type': ['ORG', 'ORG', 'ORG'], 'relationship': ['Invests_In', 'Acquiring', 'Acquiring'], 'object': ['Renew Power Ventures Pvt. Ltd.', '6.3 Percent Stake', 'Stake'], 'object_type': ['COMP', 'ECON_INDICATOR', 'ECON_INDICATOR']}
# Doc #1:
# Total pairs:  27
# Total similarity count:  17.87
# Cosine similarity 'score':  66.18
# ----------------------------------------------------
# {'subject': ['Bob Fenwick', 'BR Communications'], 'subject_type': ['PERSON', 'COMP'], 'relationship': ['Sell', 'Produce'], 'object': ['Hilltop Estate', 'Military-Communications Equipment'], 'object_type': ['PRODUCT', 'PRODUCT']}
# {'subject': ['Los Altos Hills', 'Bob Fenwick', 'BR Communications'], 'subject_type': ['GPE', 'PERSON', 'COMP'], 'relationship': ['Is_Member_Of', 'Is_Member_Of', 'Produce'], 'object': ['Silicon Valley', 'BR Communications', 'military-communications equipment'], 'object_type': ['GPE', 'COMP', 'PRODUCT']}
# {'subject': ['Bob Fenwick', 'Bob Fenwick', 'Bob Fenwick', 'BR Communications', '48-acre hilltop estate'], 'subject_type': ['PERSON', 'PERSON', 'PERSON', 'COMP', 'GPE'], 'relationship': ['Has', 'Operate_In', 'Control', 'Produce', 'Raise'], 'object': ['48-acre hilltop estate', 'Silicon Valley', 'BR Communications', 'military-communications equipment', '$30 million'], 'object_type': ['GPE', 'GPE', 'COMP', 'PRODUCT', 'FIN_INSTRUMENT']}
# Doc #2:
# Total pairs:  31
# Total similarity count:  13.24
# Cosine similarity 'score':  42.7
# ----------------------------------------------------
# {'subject': ['Sears Holdings', 'Sears Holdings'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Close', 'Close'], 'object': ['Kmart Stores', 'Sears Stores'], 'object_type': ['PRODUCT', 'PRODUCT']}
# {'subject': ['Sears Holdings Corp', 'Sears Holdings Corp'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Announce', 'Close'], 'object': ['Closing 64 Kmart stores, 39 Sears stores', 'Kmart and Sears stores'], 'object_type': ['EVENT', 'PRODUCT']}
# {'subject': ['Sears Holdings Corp', 'Sears Holdings Corp', 'Sears Holdings Corp', 'Sears Holdings Corp'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP'], 'relationship': ['Has', 'Has', 'Announce', 'Operate_In'], 'object': ['64 Kmart stores', '39 Sears stores', 'closing these stores', 'early March and early April 2018'], 'object_type': ['COMP', 'COMP', 'EVENT', 'EVENT']}
# Doc #3:
# Total pairs:  20
# Total similarity count:  14.43
# Cosine similarity 'score':  72.15
# ----------------------------------------------------
# {'subject': ['Roger Federer', 'Roger Federer'], 'subject_type': ['PERSON', 'PERSON'], 'relationship': ['Participates_In', 'Participates_In'], 'object': ['Australian Open', '20th Grand Slam Title'], 'object_type': ['EVENT', 'EVENT']}
# {'subject': ['Roger Federer', 'Roger Federer', 'Roger Federer'], 'subject_type': ['PERSON', 'PERSON', 'PERSON'], 'relationship': ['Participates_In', 'Participates_In', 'Participates_In'], 'object': ['Australian Open', 'Australian Open', 'Australian Open'], 'object_type': ['EVENT', 'EVENT', 'EVENT']}
# {'subject': ['Roger Federer', 'Roger Federer', 'Roger Federer', '20th grand slam title'], 'subject_type': ['PERSON', 'PERSON', 'PERSON', 'EVENT'], 'relationship': ['Has', 'Win', 'Clinch', 'Be'], 'object': ['Australian Open trophy', 'Australian Open', '20th grand slam title', "very 'special'"], 'object_type': ['PRODUCT', 'EVENT', 'EVENT', 'CONCEPT']}
# Doc #4:
# Total pairs:  26
# Total similarity count:  18.15
# Cosine similarity 'score':  69.8
# ----------------------------------------------------
# {'subject': ['Argos Therapeutics', 'Argos Therapeutics'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Announce', 'Raise'], 'object': ['One-For-Twenty Reverse Stock Split', 'Common Stock Value'], 'object_type': ['EVENT', 'FIN_INSTRUMENT']}
# {'subject': ['Argos Therapeutics Board', 'Argos Therapeutics Inc', 'Argos Therapeutics Board'], 'subject_type': ['ORG', 'COMP', 'ORG'], 'relationship': ['Approves', 'Announce', 'Approved'], 'object': ['One-For-Twenty Reverse Split', 'One-For-Twenty Reverse Stock Split', 'One-For-Twenty Reverse Split'], 'object_type': ['FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT']}
# {'subject': ['Argos Therapeutics Inc', 'Argos Therapeutics Inc', 'Argos Therapeutics Inc'], 'subject_type': ['COMP', 'COMP', 'COMP'], 'relationship': ['Announce', 'Has', 'Raise'], 'object': ['One-For-Twenty Reverse Stock Split', 'Board', 'Common Stock'], 'object_type': ['FIN_INSTRUMENT', 'ORG', 'FIN_INSTRUMENT']}
# Doc #5:
# Total pairs:  21
# Total similarity count:  13.62
# Cosine similarity 'score':  64.85
# ----------------------------------------------------
# {'subject': [], 'subject_type': [], 'relationship': [], 'object': [], 'object_type': []}
# {'subject': ['East Coast', 'National Weather Service', 'U.S.'], 'subject_type': ['GPE', 'ORGGOV', 'GPE'], 'relationship': ['Is_Member_Of', 'Announce', 'Is_Member_Of'], 'object': ['U.S.', 'bitterly cold temperatures and dangerous wind chills', 'East Coast'], 'object_type': ['GPE', 'EVENT', 'GPE']}
# {'subject': ['East Coast', 'East Coast', 'major winter storm', 'major winter storm', 'National Weather Service', 'bitterly cold temperatures and dangerous wind chills'], 'subject_type': ['GPE', 'GPE', 'EVENT', 'EVENT', 'ORG', 'EVENT'], 'relationship': ['Has', 'Positive_Impact_On', 'Positive_Impact_On', 'Impact', 'Announce', 'Impact'], 'object': ['major winter storm', 'heating demand', 'energy prices', 'extreme cold', 'bitterly cold temperatures and dangerous wind chills', 'Southeast to New England'], 'object_type': ['EVENT', 'CONCEPT', 'ECON_INDICATOR', 'EVENT', 'EVENT', 'GPE']}
# Doc #6:
# Total pairs:  18
# Total similarity count:  8.43
# Cosine similarity 'score':  46.83
# ----------------------------------------------------
# {'subject': ['Donald Trump', 'United States'], 'subject_type': ['PERSON', 'GPE'], 'relationship': ['Announce', 'Participates_In'], 'object': ['United States', 'NAFTA', 'EVENT'], 'object_type': ['GPE', 'EVENT']}
# {'subject': ['Canada', 'Canada', 'Donald Trump', 'United States', 'United States', 'Donald Trump'], 'subject_type': ['GPE', 'GPE', 'PERSON', 'GPE', 'GPE', 'PERSON'], 'relationship': ['Is_Member_Of', 'Is_Member_Of', 'Announce', 'Is_Member_Of', 'Is_Member_Of', 'Announce'], 'object': ['NAFTA', 'NAFTA', 'NAFTA', 'NAFTA', 'NAFTA', 'NAFTA'], 'object_type': ['EVENT', 'EVENT', 'EVENT', 'EVENT', 'EVENT', 'EVENT']}
# {'subject': ['United States', 'President Donald Trump', 'President Donald Trump', 'President Donald Trump', 'Canada'], 'subject_type': ['GPE', 'PERSON', 'PERSON', 'PERSON', 'GPE'], 'relationship': ['Introduce', 'Announce', 'Impact', 'Negative_Impact_On', 'Has'], 'object': ['NAFTA', 'NAFTA', 'NAFTA', 'Canada', 'NAFTA'], 'object_type': ['EVENT', 'EVENT', 'EVENT', 'GPE', 'EVENT']}
# Doc #7:
# Total pairs:  52
# Total similarity count:  28.92
# Cosine similarity 'score':  55.61
# ----------------------------------------------------
# {'subject': ['VT Industrial Technology Co Ltd', 'VT Industrial Technology Co Ltd'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Announce', 'Impact'], 'object': ['FY 2017 Net Profit', 'Core Business Growth', 'ECON_INDICATOR', 'CONCEPT'], 'object_type': ['ECON_INDICATOR', 'CONCEPT']}
# {'subject': ['VT Industrial Technology Co Ltd', 'VT Industrial Technology Co Ltd'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Announce', 'Has'], 'object': ['FY 2017 net profit increase', 'FY 2016 net profit'], 'object_type': ['ECON_INDICATOR', 'ECON_INDICATOR']}
# {'subject': ['VT Industrial Technology Co Ltd', 'VT Industrial Technology Co Ltd', 'VT Industrial Technology Co Ltd', 'VT Industrial Technology Co Ltd'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP'], 'relationship': ['Announce', 'Announce', 'Positive_Impact_On', 'Positive_Impact_On'], 'object': ['FY 2017 net profit', 'FY 2016 net profit', 'improved profitability', 'steady growth of core business'], 'object_type': ['ECON_INDICATOR', 'ECON_INDICATOR', 'CONCEPT', 'CONCEPT']}
# Doc #8:
# Total pairs:  20
# Total similarity count:  13.12
# Cosine similarity 'score':  65.59
# ----------------------------------------------------
# {'subject': ['Intermolecular Inc', 'Intermolecular Inc', 'Intermolecular Inc'], 'subject_type': ['COMP', 'COMP', 'COMP'], 'relationship': ['Announce', 'Deliver', 'Work_Together'], 'object': ['SITRI', 'Critical Unit Films', 'SITRI'], 'object_type': ['ORG', 'PRODUCT', 'ORG']}
# {'subject': ['Intermolecular Inc', 'Intermolecular Inc', 'Intermolecular Inc', 'Intermolecular Inc', 'SITRI', 'Intermolecular Inc', 'SITRI'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP', 'COMP', 'COMP', 'COMP'], 'relationship': ['Relate_To', 'Operate_In', 'Produce', 'Has', 'Relate_To', 'Participates_In', 'Participates_In'], 'object': ['China Market', 'China Market', 'Memory Device', 'Strategic Alliance', 'Intermolecular Inc', 'SITRI', 'Intermolecular Inc'], 'object_type': ['GPE', 'GPE', 'PRODUCT', 'CONCEPT', 'COMP', 'COMP', 'COMP']}
# {'subject': ['Intermolecular Inc', 'Intermolecular Inc', 'Intermolecular Inc', 'Intermolecular Inc', 'Intermolecular Inc'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP', 'COMP'], 'relationship': ['Expand', 'Operate_In', 'Delivering', 'Work_With', 'Work_Towards'], 'object': ['Strategic Alliance', 'China Market', 'Critical Unit Films', 'Sitri', 'Producing a Working Memory Device'], 'object_type': ['CONCEPT', 'GPE', 'PRODUCT', 'ORG', 'CONCEPT']}
# Doc #9:
# Total pairs:  71
# Total similarity count:  51.88
# Cosine similarity 'score':  73.07
# ----------------------------------------------------
# {'subject': [], 'subject_type': [], 'relationship': [], 'object': [], 'object_type': []}
# {'subject': ['dollar', 'U.S.', 'dollar', 'U.S.'], 'subject_type': ['FIN_INSTRUMENT', 'GPE', 'FIN_INSTRUMENT', 'GPE'], 'relationship': ['Positive_Impact_On', 'Has', 'Relate_To', 'Has'], 'object': ['U.S. economic expansion', 'economic expansion', 'U.S. economic expansion', 'industrial output'], 'object_type': ['CONCEPT', 'CONCEPT', 'CONCEPT', 'ECON_INDICATOR']}
# {'subject': ['The dollar', 'The dollar', 'The dollar', 'The dollar', 'The dollar', 'The index that tracks the greenback', 'The index that tracks the greenback', 'The index that tracks the greenback'], 'subject_type': ['FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT'], 'relationship': ['held', 'held', 'held', 'versus', 'supported', 'against', 'was last up', 'fell'], 'object': ['gains', 'gains', 'gains', 'a basket of currencies', 'the notion of a steady U.S. economic expansion', 'six other major currencies', '0.27 percent', 'to a three-year low'], 'object_type': ['CONCEPT', 'FIN_INSTRUMENT', 'ECON_INDICATOR', 'FIN_INSTRUMENT', 'CONCEPT', 'FIN_INSTRUMENT', 'ECON_INDICATOR', 'CONCEPT']}
# Doc #10:
# Total pairs:  32
# Total similarity count:  12.66
# Cosine similarity 'score':  39.56
# ----------------------------------------------------
# {'subject': ['Brixmor Property Group Inc', 'Brixmor Operating Partnership LP'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Announce', 'May Offer'], 'object': ['Mixed Shelf Offering', 'Debt Securities'], 'object_type': ['FIN_INSTRUMENT', 'FIN_INSTRUMENT']}
# {'subject': ['Brixmor Property Group Inc', 'Brixmor Property Group Inc', 'Brixmor Operating Partnership LP'], 'subject_type': ['COMP', 'COMP', 'COMP'], 'relationship': ['Files', 'May Offer', 'Operate_In'], 'object': ['A Potential Mixed Shelf Offering', 'Debt Securities', 'One Or More Series'], 'object_type': ['FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT']}
# {'subject': ['Brixmor Property Group Inc', 'Brixmor Property Group Inc', 'Brixmor Operating Partnership LP'], 'subject_type': ['COMP', 'COMP', 'ORG'], 'relationship': ['Files', 'Operate_In', 'May Offer'], 'object': ['Potential Mixed Shelf Offering', 'Brixmor Operating Partnership LP', 'Debt Securities'], 'object_type': ['CONCEPT', 'ORG', 'FIN_INSTRUMENT']}
# Doc #11:
# Total pairs:  21
# Total similarity count:  11.87
# Cosine similarity 'score':  56.52
# ----------------------------------------------------
# {'subject': ['John Hancock', 'John Hancock'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Announce', 'Announce'], 'object': ['Brooks Tingle', 'Linda Levyne'], 'object_type': ['PERSON', 'PERSON']}
# {'subject': ['John Hancock', 'John Hancock', 'Brooks Tingle', 'Brooks Tingle', 'Linda Levyne'], 'subject_type': ['ORG', 'ORG', 'PERSON', 'PERSON', 'PERSON'], 'relationship': ['Is_Member_Of', 'Announce', 'Is_Member_Of', 'Relate_To', 'Relate_To'], 'object': ['Manulife Financial', 'Brooks Tingle', 'John Hancock', 'Linda Levyne', 'John Hancock'], 'object_type': ['ORG', 'PERSON', 'ORG', 'PERSON', 'ORG']}
# {'subject': ['John Hancock', 'John Hancock', 'Brooks Tingle', 'Linda Levyne'], 'subject_type': ['COMP', 'COMP', 'PERSON', 'PERSON'], 'relationship': ['Has', 'Has', 'Operate_In', 'Operate_In'], 'object': ['Brooks Tingle', 'Linda Levyne', 'John Hancock', 'John Hancock'], 'object_type': ['PERSON', 'PERSON', 'COMP', 'COMP']}
# Doc #12:
# Total pairs:  38
# Total similarity count:  25.31
# Cosine similarity 'score':  66.6
# ----------------------------------------------------
# {'subject': ['Toyou Feiji Electronics Co Ltd', 'Toyou Feiji Electronics Co Ltd'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Decrease', 'Relate_To'], 'object': ['Net Profit', 'R&D Expenses', 'Software Product VAT Refund'], 'object_type': ['ECON_INDICATOR', 'CONCEPT', 'CONCEPT']}
# {'subject': ['Tyou Feiji Electronics Co Ltd', 'Tyou Feiji Electronics Co Ltd', 'Tyou Feiji Electronics Co Ltd'], 'subject_type': ['COMP', 'COMP', 'COMP'], 'relationship': ['Forecast', 'Announce', 'Relate_To'], 'object': ['FY 2017 net profit', 'FY 2016 net profit', 'R&D expenses'], 'object_type': ['ECON_INDICATOR', 'ECON_INDICATOR', 'FIN_INSTRUMENT']}
# {'subject': ['Toyou Feiji Electronics Co Ltd', 'Toyou Feiji Electronics Co Ltd', 'Toyou Feiji Electronics Co Ltd', 'FY 2017 net profit to decrease', 'Increased R&D expenses', 'Decreased software product related value-added-tax refund'], 'subject_type': ['COMP', 'COMP', 'COMP', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR'], 'relationship': ['Announce', 'Decrease', 'Has', 'Impact', 'Relate_To', 'Relate_To'], 'object': ['FY 2017 net profit to decrease', 'FY 2017 net profit', 'FY 2016 net profit', 'Toyou Feiji Electronics Co Ltd', 'Toyou Feiji Electronics Co Ltd', 'Toyou Feiji Electronics Co Ltd'], 'object_type': ['ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'COMP', 'COMP', 'COMP']}
# Doc #13:
# Total pairs:  36
# Total similarity count:  22.32
# Cosine similarity 'score':  62.0
# ----------------------------------------------------
# {'subject': ['Narendra Modi', 'Narendra Modi', 'World Economic Forum'], 'subject_type': ['PERSON', 'PERSON', 'EVENT'], 'relationship': ['Participates_In', 'Announce', 'Relate_To'], 'object': ['World Economic Forum', 'Rising Protectionist Policies', 'Rising Protectionist Policies'], 'object_type': ['EVENT', 'CONCEPT', 'CONCEPT']}
# {'subject': ['Narendra Modi', 'Narendra Modi', 'World Economic Forum'], 'subject_type': ['PERSON', 'PERSON', 'ORG'], 'relationship': ['Participates_In', 'Negative_Impact_On', 'Operate_In'], 'object': ['World Economic Forum', 'Protectionist Policies', 'Davos'], 'object_type': ['EVENT', 'CONCEPT', 'GPE']}
# {'subject': ['Indian Prime Minister Narendra Modi', 'Indian Prime Minister Narendra Modi', 'Indian Prime Minister Narendra Modi', 'Indian Prime Minister Narendra Modi'], 'subject_type': ['PERSON', 'PERSON', 'PERSON', 'PERSON'], 'relationship': ['Urge', 'Participates_In', 'Has', 'Negative_Impact_On'], 'object': ['listeners', 'World Economic Forum', 'opening speech', 'rising protectionist policies'], 'object_type': ['CONCEPT', 'EVENT', 'CONCEPT', 'CONCEPT']}
# Doc #14:
# Total pairs:  33
# Total similarity count:  18.45
# Cosine similarity 'score':  55.9
# ----------------------------------------------------
# {'subject': ['General Electric', 'General Electric'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Announce', 'Negative_Impact_On'], 'object': ['Tax Changes and Insurance Portfolio', 'Shares'], 'object_type': ['CONCEPT', 'FIN_INSTRUMENT']}
# {'subject': ['General Electric', 'General Electric'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Take', 'Has'], 'object': ['$11 billion charge', 'Insurance Portfolio'], 'object_type': ['FIN_INSTRUMENT', 'PRODUCT']}
# {'subject': ['General Electric', 'General Electric', 'General Electric', 'General Electric'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP'], 'relationship': ['Has', 'Has', 'Decrease', 'Announce'], 'object': ['Tax Changes', 'Insurance Portfolio', 'General Electric Shares', '$11 billion charge'], 'object_type': ['CONCEPT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'ECON_INDICATOR']}
# Doc #15:
# Total pairs:  20
# Total similarity count:  11.73
# Cosine similarity 'score':  58.65
# ----------------------------------------------------
# {'subject': ['Plaza Retail REIT', 'Plaza Retail REIT'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Acquires', 'Invests_In'], 'object': ['Redevelopment Site', 'Redevelopment Site'], 'object_type': ['PRODUCT', 'PRODUCT']}
# {'subject': ['Plaza Retail REIT', 'Plaza Retail REIT', 'Plaza Retail REIT', 'Plaza Retail REIT'], 'subject_type': ['ORG', 'ORG', 'ORG', 'ORG'], 'relationship': ['Acquires', 'Announce', 'Invests_In', 'Raise'], 'object': ['Redevelopment Site In Brockville, ON', 'Deal', 'Borrowing Facility', 'Cash'], 'object_type': ['GPE', 'EVENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT']}
# {'subject': ['Plaza Retail Reit', 'Plaza Retail Reit', 'Plaza Retail Reit', 'New Borrowing Facility'], 'subject_type': ['COMP', 'COMP', 'COMP', 'FIN_INSTRUMENT'], 'relationship': ['Acquires', 'Satisfied', 'Satisfied', 'Has'], 'object': ['Redevelopment Site In Brockville, ON', 'Purchase Price', 'New Borrowing Facility', 'Cost of Prime Plus 1.25%'], 'object_type': ['GPE', 'ECON_INDICATOR', 'FIN_INSTRUMENT', 'ECON_INDICATOR']}
# Doc #16:
# Total pairs:  32
# Total similarity count:  16.76
# Cosine similarity 'score':  52.37
# ----------------------------------------------------
# {'subject': ['Federal Reserve', 'Federal Reserve'], 'subject_type': ['ORGREG', 'ORGREG'], 'relationship': ['Raise', 'Impact'], 'object': ['Interest Rates', 'Banks', 'Banks'], 'object_type': ['ECON_INDICATOR', 'ORG', 'ORG']}
# {'subject': ['Savings accounts', 'Federal Reserve', 'Savings account yields', 'Federal Reserve', 'banks'], 'subject_type': ['PRODUCT', 'ORGREG', 'PRODUCT', 'ORGREG', 'ORG'], 'relationship': ['Relate_To', 'Control', 'Relate_To', 'Impact', 'Negative_Impact_On'], 'object': ['higher returns', 'interest rates', 'interest rates', 'deposit rates', 'certain banks'], 'object_type': ['CONCEPT', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ORG']}
# {'subject': ['Savings Accounts', 'Savings Accounts', 'Savings Accounts', 'Investors', 'Scramble', 'Certain Banks', 'Savings Account Yields', 'Savings Account Yields', 'Federal Reserve', 'Federal Reserve', 'More Banks', 'Savers', 'Banks'], 'subject_type': ['FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'PERSON', 'EVENT', 'ORG', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ORGREG', 'ORGREG', 'ORG', 'PERSON', 'ORG'], 'relationship': ['Pay', 'Has', 'Positive_Impact_On', 'Participates_In', 'Relate_To', 'Negative_Impact_On', 'Has', 'Relate_To', 'Operate_In', 'Raise', 'Raise', 'Respond', 'Pay'], 'object': ['Nothing', 'Yields', 'Investors', 'Scramble', 'Higher Returns', 'Bad News', 'No Change', 'Federal Reserve', 'Interest Rates', 'Interest Rates', 'Deposit Rates', 'Rushing to Banks', 'Most'], 'object_type': ['ECON_INDICATOR', 'ECON_INDICATOR', 'PERSON', 'EVENT', 'ECON_INDICATOR', 'CONCEPT', 'ECON_INDICATOR', 'ORGREG', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'EVENT', 'ECON_INDICATOR']}
# Doc #17:
# Total pairs:  101
# Total similarity count:  49.17
# Cosine similarity 'score':  48.68
# ----------------------------------------------------
# {'subject': ['Versace', 'Versace'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Announce', 'Relate_To'], 'object': ['Act of Fiction', 'The Assassination of Gianni Versace: American Crime Story', 'EVENT'], 'object_type': ['CONCEPT', 'EVENT']}
# {'subject': ['Versace company', 'Versace company', 'The Assassination of Gianni Versace', 'Gianni Versace', 'The Assassination of Gianni Versace'], 'subject_type': ['ORG', 'ORG', 'EVENT', 'PERSON', 'EVENT'], 'relationship': ['Issue', 'Call', 'Premier', 'Relate_To', 'Premier'], 'object': ['statement', 'it', 'Versace company', 'Versace company', 'Versace company'], 'object_type': ['CONCEPT', 'CONCEPT', 'ORG', 'ORG', 'ORG']}
# {'subject': ['Versace Company', 'Versace Company', 'The Assassination of Gianni Versace: American Crime Story', 'The Assassination of Gianni Versace: American Crime Story', 'The Assassination of Gianni Versace: American Crime Story', 'Versace Company'], 'subject_type': ['COMP', 'COMP', 'EVENT', 'EVENT', 'EVENT', 'COMP'], 'relationship': ['Issue', 'Call', 'Premiere', 'Relate_To', 'Treat', 'Produce'], 'object': ['Statement', 'The Assassination of Gianni Versace: American Crime Story', 'The Assassination of Gianni Versace: American Crime Story', 'Gianni Versace', 'Versace Family', 'The Assassination of Gianni Versace: American Crime Story'], 'object_type': ['CONCEPT', 'EVENT', 'EVENT', 'PERSON', 'ORG', 'EVENT']}
# Doc #18:
# Total pairs:  52
# Total similarity count:  22.89
# Cosine similarity 'score':  44.01
# ----------------------------------------------------
# {'subject': ['Capita Plc', 'Capita Plc', 'Life and Pensions Operations'], 'subject_type': ['COMP', 'COMP', 'PRODUCT'], 'relationship': ['Announce', 'Continue', 'Contribute'], 'object': ['New Supplier', 'Prudential’s International Operations', 'Revenue of £80M', 'COMP'], 'object_type': ['COMP', 'COMP', 'CONCEPT']}
# {'subject': ['Capita Plc', 'Capita Plc', 'Life and Pensions Operations'], 'subject_type': ['COMP', 'COMP', 'PRODUCT'], 'relationship': ['Announce', 'Operate_In', 'Relate_To'], 'object': ['Transfer of Administration', 'Prudential‘s International Operations', 'Capita Plc'], 'object_type': ['EVENT', 'PRODUCT', 'COMP']}
# {'subject': ['Capita Plc'], 'subject_type': ['COMP'], 'relationship': ['Announce', 'Administer', 'Contribute'], 'object': ['Administration of its Life and Pensions Business', "Prudential's International Operations", 'Revenue'], 'object_type': ['EVENT', 'ORG', 'ECON_INDICATOR']}
# Doc #19:
# Total pairs:  15
# Total similarity count:  9.52
# Cosine similarity 'score':  63.46
# ----------------------------------------------------
# {'subject': ['Morgan Stanley'], 'subject_type': ['COMP'], 'relationship': ['Impact'], 'object': ['U.S. Tax Code Overhaul', 'CONCEPT'], 'object_type': ['CONCEPT']}
# {'subject': ['Morgan Stanley', 'Morgan Stanley'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Impact', 'Relate_To'], 'object': ['U.S. tax code overhaul', 'U.S. tax code overhaul'], 'object_type': ['EVENT', 'EVENT']}
# {'subject': ['Morgan Stanley', 'Morgan Stanley', 'Morgan Stanley'], 'subject_type': ['COMP', 'COMP', 'COMP'], 'relationship': ['Raise', 'Decrease', 'Relate_To'], 'object': ['Corporate Tax Rate', 'Fourth-Quarter Earnings', 'U.S. Tax Code Overhaul'], 'object_type': ['ECON_INDICATOR', 'ECON_INDICATOR', 'CONCEPT']}
# Doc #20:
# Total pairs:  11
# Total similarity count:  7.6
# Cosine similarity 'score':  69.09
# ----------------------------------------------------
# {'subject': ['Connecticut Democrats', 'Tony Guerrera'], 'subject_type': ['ORGGOV', 'PERSON'], 'relationship': ['Announce', 'Propose'], 'object': ['Highway Tolls', 'Legislation'], 'object_type': ['CONCEPT', 'CONCEPT']}
# {'subject': ['Connecticut Democrats', 'State Rep. Tony Guerrera', 'Tony Guerrera'], 'subject_type': ['ORG', 'PERSON', 'PERSON'], 'relationship': ['Call_For', 'Propose', 'Is_Member_Of'], 'object': ['highway tolls', 'legislation', 'transportation committee'], 'object_type': ['ECON_INDICATOR', 'CONCEPT', 'ORG']}
# {'subject': ['Connecticut Democrats', 'Connecticut Democrats', 'State Rep. Tony Guerrera'], 'subject_type': ['ORG', 'ORG', 'PERSON'], 'relationship': ['renew calls for', 'reignite', 'propose legislation'], 'object': ['reinstating highway tolls', 'debate', 'draft a statewide plan'], 'object_type': ['EVENT', 'CONCEPT', 'EVENT']}
# Doc #21:
# Total pairs:  21
# Total similarity count:  11.17
# Cosine similarity 'score':  53.19
# ----------------------------------------------------
# {'subject': ['Sudan', 'Sudan'], 'subject_type': ['GPE', 'GPE'], 'relationship': ['Announce', 'Recall'], 'object': ['Ambassador to Egypt', 'Ambassador to Egypt'], 'object_type': ['PERSON', 'PERSON']}
# {'subject': ['Sudan', 'Sudan', 'Khalid Abdelaziz', 'Nadine Awadalla', 'Andrew Heavens'], 'subject_type': ['GPE', 'GPE', 'PERSON', 'PERSON', 'PERSON'], 'relationship': ['Recall', 'Operate_In', 'Participates_In', 'Participates_In', 'Participates_In'], 'object': ['Egypt', 'Egypt', 'Talks', 'Talks', 'Talks'], 'object_type': ['GPE', 'GPE', 'EVENT', 'EVENT', 'EVENT']}
# {'subject': ['Sudan', 'Sudan', 'ambassador'], 'subject_type': ['GPE', 'GPE', 'PERSON'], 'relationship': ['Has', 'Recall', 'Operate_In'], 'object': ['ambassador', 'ambassador', 'Egypt'], 'object_type': ['PERSON', 'PERSON', 'GPE']}
# Doc #22:
# Total pairs:  31
# Total similarity count:  14.95
# Cosine similarity 'score':  48.22
# ----------------------------------------------------
# {'subject': ['Floor & Decor Holdings Inc', 'Floor & Decor Holdings Inc', 'Floor & Decor Holdings Inc'], 'subject_type': ['COMP', 'COMP', 'COMP'], 'relationship': ['Announce', 'Announce', 'Announce'], 'object': ['Q4 Net Sales', 'Adjusted Diluted EPS', 'Q4 Comparable Store Sales Growth'], 'object_type': ['ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR']}
# {'subject': ['Floor & Decor Holdings Inc', 'Floor & Decor Holdings Inc', 'Floor & Decor Holdings Inc', 'Floor & Decor Holdings Inc', 'Thomson Reuters I/B/E/S'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP', 'ORG'], 'relationship': ['Announce', 'Announce', 'Announce', 'Announce', 'Relate_To'], 'object': ['NET SALES', 'ADJUSTED DILUTED EPS', 'COMPARABLE STORE SALES GROWTH', 'EARNINGS PER SHARE VIEW', 'Further company coverage'], 'object_type': ['ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'CONCEPT']}
# {'subject': ['Floor & Decor Holdings Inc', 'Floor & Decor Holdings Inc', 'Floor & Decor Holdings Inc', 'Floor & Decor Holdings Inc', 'Floor & Decor Holdings Inc', 'Floor & Decor Holdings Inc'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP', 'COMP', 'COMP'], 'relationship': ['Has', 'Has', 'Sees', 'Estimates', 'Has', 'Has'], 'object': ['Q4 Net Sales', 'Preliminary Adjusted Diluted EPS', 'Q4 Comparable Store Sales Growth', 'Q4 EPS', 'Q4 Earnings Per Share View', 'Q4 Revenue View'], 'object_type': ['ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR']}
# Doc #23:
# Total pairs:  63
# Total similarity count:  35.32
# Cosine similarity 'score':  56.06
# ----------------------------------------------------
# {'subject': ['S&P 500', 'Healthcare', 'Financial', 'Dow Jones Industrial Average', 'Nasdaq Composite'], 'subject_type': ['FIN_INSTRUMENT', 'SECTOR', 'SECTOR', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT'], 'relationship': ['Impact', 'Weigh', 'Weigh', 'Impact', 'Impact'], 'object': ['Earnings Season', 'S&P 500', 'S&P 500', 'Investors', 'Investors'], 'object_type': ['EVENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'CONCEPT', 'CONCEPT']}
# {'subject': ['S&P 500', 'healthcare and financial sectors', 'investors', 'Dow Jones Industrial Average', 'S&P 500', 'Nasdaq Composite'], 'subject_type': ['FIN_INSTRUMENT', 'SECTOR', 'PERSON', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT'], 'relationship': ['Relate_To', 'Negative_Impact_On', 'Participates_In', 'Decrease', 'Raise', 'Raise'], 'object': ['Monday', 'investors', 'earnings season', 'points', 'points', 'points'], 'object_type': ['EVENT', 'PERSON', 'EVENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT']}
# {'subject': ['S&P 500', 'Healthcare Sector', 'Financial Sector', 'Investors', 'Investors', 'Strong Rally', 'Dow Jones Industrial Average', 'Dow Jones Industrial Average', 'Dow Jones Industrial Average', 'S&P 500', 'S&P 500', 'S&P 500', 'Nasdaq Composite', 'Nasdaq Composite', 'Nasdaq Composite'], 'subject_type': ['FIN_INSTRUMENT', 'SECTOR', 'SECTOR', 'PERSON', 'PERSON', 'EVENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT'], 'relationship': ['Rise', 'Weigh', 'Weigh', 'Take_Breather', 'Take_Breather', 'Mark', 'Fall', 'Fall', 'Fall', 'Gain', 'Gain', 'Gain', 'Add', 'Add', 'Add'], 'object': ['Monday', 'S&P 500', 'S&P 500', 'Earnings Season', 'Strong Rally', 'Start of 2018', '12.94 points', '0.05 percent', '25,282.93', '4.55 points', '0.17 percent', '2,747.7', '20.83 points', '0.29 percent', '7,157.39'], 'object_type': ['EVENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'EVENT', 'EVENT', 'EVENT', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR']}
# Doc #24:
# Total pairs:  195
# Total similarity count:  62.21
# Cosine similarity 'score':  31.9
# ----------------------------------------------------
# {'subject': ['Wooriro Co Ltd'], 'subject_type': ['COMP'], 'relationship': ['Raise'], 'object': ['Facilities and Investment', 'Operations'], 'object_type': ['CONCEPT', 'CONCEPT']}
# {'subject': ['Wooriro Co Ltd', 'Wooriro Co Ltd', 'Wooriro Co Ltd', 'Wooriro Co Ltd', 'Wooriro Co Ltd'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP', 'COMP'], 'relationship': ['Issue', 'Raise', 'Has', 'Has', 'Has'], 'object': ['10th series unregistered and unsecured private convertible bonds', 'proceeds for facilities and investment as well as operations', 'Jan. 24, 2021', '4 percent', '3,098 won/share'], 'object_type': ['FIN_INSTRUMENT', 'ECON_INDICATOR', 'EVENT', 'ECON_INDICATOR', 'ECON_INDICATOR']}
# {'subject': ['Wooriro Co Ltd', 'Wooriro Co Ltd', 'Wooriro Co Ltd', '10th series unregistered and unsecured private convertible bonds', '10th series unregistered and unsecured private convertible bonds', '10th series unregistered and unsecured private convertible bonds', '10th series unregistered and unsecured private convertible bonds', '10th series unregistered and unsecured private convertible bonds'], 'subject_type': ['COMP', 'COMP', 'COMP', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT'], 'relationship': ['Raise', 'Introduce', 'Operate_In', 'Has', 'Has', 'Has', 'Has', 'Has'], 'object': ['10 billion won', '10th series unregistered and unsecured private convertible bonds', 'facilities and investment as well as operations', 'Maturity date', 'coupon rate', 'yield to maturity', 'conversion price', 'conversion ratio'], 'object_type': ['ECON_INDICATOR', 'FIN_INSTRUMENT', 'CONCEPT', 'CONCEPT', 'CONCEPT', 'CONCEPT', 'CONCEPT', 'CONCEPT']}
# Doc #25:
# Total pairs:  53
# Total similarity count:  27.41
# Cosine similarity 'score':  51.71
# ----------------------------------------------------
# {'subject': ['John Cornyn', 'Fox News Channel'], 'subject_type': ['PERSON', 'ORG'], 'relationship': ['Predict', 'Report'], 'object': ['U.S. government', 'U.S. government shutdown'], 'object_type': ['ORGGOV', 'EVENT']}
# {'subject': ['U.S. government', 'John Cornyn', 'John Cornyn'], 'subject_type': ['ORGGOV', 'PERSON', 'PERSON'], 'relationship': ['Relate_To', 'Participates_In', 'Is_Member_Of'], 'object': ['Monday', 'lawmakers', 'Senate'], 'object_type': ['EVENT', 'ORGGOV', 'ORGGOV']}
# {'subject': ['John Cornyn', 'John Cornyn', 'John Cornyn'], 'subject_type': ['PERSON', 'PERSON', 'PERSON'], 'relationship': ['Predict', 'Operate_In', 'Is_Member_Of'], 'object': ['U.S. government', 'Senate', 'Republican'], 'object_type': ['ORGGOV', 'ORG', 'ORG']}
# Doc #26:
# Total pairs:  21
# Total similarity count:  11.15
# Cosine similarity 'score':  53.09
# ----------------------------------------------------
# {'subject': ['Bank of Japan', 'Bank of Japan'], 'subject_type': ['ORGGOV', 'ORGGOV'], 'relationship': ['Announce', 'Invests_In'], 'object': ["BOJ's Announcement", 'Japanese Government Bonds'], 'object_type': ['EVENT', 'FIN_INSTRUMENT']}
# {'subject': ['Bank of Japan', 'dollar', 'dollar'], 'subject_type': ['ORGREG', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT'], 'relationship': ['Increase', 'Impact', 'Negative_Impact_On'], 'object': ['Japanese government bonds', 'yen', 'yen'], 'object_type': ['FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT']}
# {'subject': ['Bank of Japan', 'Bank of Japan', 'Yen', 'Dollar', 'Dollar', 'Dollar'], 'subject_type': ['ORGREG', 'ORGREG', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR'], 'relationship': ['Increase', 'Impact', 'Slip', 'Touch', 'Pull Back', 'Trade'], 'object': ['Buying in Japanese Government Bonds', 'Yen', 'Dollar', 'Intraday High of 109.095 Yen', 'Intraday High', '108.93 Yen'], 'object_type': ['FIN_INSTRUMENT', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR']}
# Doc #27:
# Total pairs:  36
# Total similarity count:  19.89
# Cosine similarity 'score':  55.25
# ----------------------------------------------------
# {'subject': ['Japan Petroleum Exploration Co Ltd', 'Japan Petroleum Exploration Co Ltd'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Announce', 'Impact'], 'object': ['Shale Gas Project', 'Net Income'], 'object_type': ['PRODUCT', 'ECON_INDICATOR']}
# {'subject': ['Japan Petroleum Exploration Co Ltd', 'Japan Petroleum Exploration Co Ltd', 'Japan Petroleum Exploration Co Ltd', 'Japan Petroleum Exploration Co Ltd'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP'], 'relationship': ['Operate_In', 'Negative_Impact_On', 'Announce', 'Relate_To'], 'object': ['Canada', 'net income', 'impairment loss', 'shale gas project'], 'object_type': ['GPE', 'ECON_INDICATOR', 'ECON_INDICATOR', 'PRODUCT']}
# {'subject': ['Japan Petroleum Exploration Co Ltd', 'Japan Petroleum Exploration Co Ltd', 'Japan Petroleum Exploration Co Ltd', 'Impairment Loss', 'Impairment Loss'], 'subject_type': ['COMP', 'COMP', 'COMP', 'CONCEPT', 'CONCEPT'], 'relationship': ['Has', 'Has', 'Operate_In', 'Impact', 'Decrease'], 'object': ['Impairment Loss', 'Shale Gas Project', 'Canada', 'Net Income', 'Full-Year Earnings'], 'object_type': ['CONCEPT', 'CONCEPT', 'GPE', 'CONCEPT', 'CONCEPT']}
# Doc #28:
# Total pairs:  38
# Total similarity count:  18.19
# Cosine similarity 'score':  47.86
# ----------------------------------------------------
# {'subject': ['BP', 'BP', 'Deepwater Horizon Spill'], 'subject_type': ['COMP', 'COMP', 'EVENT'], 'relationship': ['Raise', 'Impact', 'Relate_To'], 'object': ['Deepwater Horizon Spill', 'Total Costs', 'BP'], 'object_type': ['EVENT', 'ECON_INDICATOR', 'COMP']}
# {'subject': ['BP', 'BP', 'BP', 'Deepwater Horizon'], 'subject_type': ['COMP', 'COMP', 'COMP', 'EVENT'], 'relationship': ['Raise', 'Raise', 'Raise', 'Relate_To'], 'object': ['$65 billion', '$65 billion', '$65 billion', '2010'], 'object_type': ['FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'EVENT']}
# {'subject': ['BP', 'BP', 'BP', 'total costs'], 'subject_type': ['COMP', 'COMP', 'COMP', 'ECON_INDICATOR'], 'relationship': ['Has', 'Raise', 'Impact', 'Decrease'], 'object': ['Deepwater Horizon spill', 'estimates for outstanding claims', 'total costs', '$65 billion'], 'object_type': ['EVENT', 'CONCEPT', 'ECON_INDICATOR', 'ECON_INDICATOR']}
# Doc #29:
# Total pairs:  40
# Total similarity count:  25.28
# Cosine similarity 'score':  63.2
# ----------------------------------------------------
# {'subject': ['Turkish Artillery', 'Ankara', 'Emily Wither'], 'subject_type': ['ORG', 'GPE', 'PERSON'], 'relationship': ['Impact', 'Announce', 'Reports'], 'object': ['Afrin Region', 'Military Campaign', 'Military Campaign'], 'object_type': ['GPE', 'EVENT', 'EVENT']}
# {'subject': ['Turkey', 'Turkish artillery'], 'subject_type': ['GPE', 'ORG'], 'relationship': ['Operate_In', 'Announce'], 'object': ['Afrin region', 'Syria operation'], 'object_type': ['GPE', 'EVENT']}
# {'subject': ['Turkish', 'Turkish', 'into', "Syria's Afrin region", 'Turkey', 'military campaign', 'Kurdish-controlled area', 'Emily Wither'], 'subject_type': ['GPE', 'GPE', 'EVENT', 'GPE', 'GPE', 'EVENT', 'GPE', 'PERSON'], 'relationship': ['Has', 'Fire', 'Impact', 'Is_Member_Of', 'Announce', 'Against', 'Relate_To', 'Reports'], 'object': ['artillery', 'into', "Syria's Afrin region", 'Syria', 'military campaign', 'Kurdish-controlled area', 'Kurdish', 'military campaign'], 'object_type': ['CONCEPT', 'EVENT', 'GPE', 'GPE', 'EVENT', 'GPE', 'PERSON', 'EVENT']}
# Doc #30:
# Total pairs:  46
# Total similarity count:  18.1
# Cosine similarity 'score':  39.34
# ----------------------------------------------------
# {'subject': ['NVIDIA Corp', 'NVIDIA Corp'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Announce', 'Relate_To'], 'object': ['Security Updates', 'Google Project Zero', 'CONCEPT'], 'object_type': ['CONCEPT', 'ORG']}
# {'subject': ['NVIDIA Corp', 'NVIDIA Corp', 'NVIDIA Corp', 'NVIDIA Corp', 'Google Project Zero', 'Google Project Zero'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP', 'ORG', 'ORG'], 'relationship': ['Provide', 'Mitigate', 'Update', 'Relate_To', 'Publish', 'Announce'], 'object': ['Security Updates', 'Aspects', 'Driver Security Updates', 'Speculative Side Channels', 'Novel Information', 'January Publication']}
# {'subject': ['NVIDIA Corp', 'NVIDIA Corp', 'NVIDIA Corp', 'Google Project Zero'], 'subject_type': ['COMP', 'COMP', 'COMP', 'ORG'], 'relationship': ['Provide', 'Mitigate', 'Relate_To', 'Publish'], 'object': ['Security Update', 'Speculative Side Channels', 'Google Project Zero', 'Novel Information'], 'object_type': ['CONCEPT', 'CONCEPT', 'ORG', 'CONCEPT']}
# Doc #31:
# Total pairs:  44
# Total similarity count:  24.93
# Cosine similarity 'score':  56.65
# ----------------------------------------------------
# {'subject': ['Republic Bancorp Inc', 'Republic Bancorp Inc'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Announce', 'Increase'], 'object': ['Quarterly Cash Dividends', 'Common Stock Cash Dividends'], 'object_type': ['FIN_INSTRUMENT', 'FIN_INSTRUMENT']}
# {'subject': ['Republic Bancorp Inc', 'Republic Bancorp Inc', 'Republic Bancorp Inc'], 'subject_type': ['COMP', 'COMP', 'COMP'], 'relationship': ['Increase', 'Announce', 'Announce'], 'object': ['Common Stock Cash Dividends', "Company's Quarterly Cash Dividends", 'Qtrly Cash Dividend'], 'object_type': ['FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT']}
# {'subject': ['Republic Bancorp Inc', 'Republic Bancorp Inc', 'Republic Bancorp Inc'], 'subject_type': ['COMP', 'COMP', 'COMP'], 'relationship': ['Announce', 'Raise', 'Raise'], 'object': ["10% Increase in Company's Quarterly Cash Dividends", 'Quarterly Cash Dividend of $0.242 per share of Class A Common Stock', 'Quarterly Cash Dividend of $0.22 per share on Class B Common Stock'], 'object_type': ['FIN_INSTRUMENT', 'FIN_INSTRUMENT', 'FIN_INSTRUMENT']}
# Doc #32:
# Total pairs:  21
# Total similarity count:  16.56
# Cosine similarity 'score':  78.85
# ----------------------------------------------------
# {'subject': ['Astellas Pharma Inc', 'Astellas Pharma Inc', 'Blinatumomab'], 'subject_type': ['COMP', 'COMP', 'PRODUCT'], 'relationship': ['Announce', 'Introduce', 'Treat'], 'object': ['Marketing Authorization', 'Blinatumomab', 'B-cell Precursor Acute Lymphoblastic Leukemia'], 'object_type': ['CONCEPT', 'PRODUCT', 'CONCEPT']}
# {'subject': ['Astellas Pharma Inc', 'Amgen Astellas BioPharma', 'Astellas Pharma Inc'], 'subject_type': ['COMP', 'COMP', 'COMP'], 'relationship': ['Announce', 'Is_Member_Of', 'Introduce'], 'object': ['blinatumomab', 'Amgen Astellas BioPharma', 'blinatumomab'], 'object_type': ['PRODUCT', 'COMP', 'PRODUCT']}
# {'subject': ['Astellas Pharma Inc', 'Astellas Pharma Inc', 'application', 'application', 'application'], 'subject_type': ['COMP', 'COMP', 'PRODUCT', 'PRODUCT', 'PRODUCT'], 'relationship': ['Announce', 'Jointly_Develop', 'Submitted', 'For_Treatment', 'Has'], 'object': ['application', 'Amgen Astellas BioPharma', 'Japan', 'relapsed or refractory B-cell precursor acute lymphoblastic leukemia', 'bispecific CD19-directed CD3 T cell engager (BiTE®) antibody construct blinatumomab'], 'object_type': ['PRODUCT', 'ORG', 'GPE', 'CONCEPT', 'PRODUCT']}
# Doc #33:
# Total pairs:  39
# Total similarity count:  18.59
# Cosine similarity 'score':  47.66
# ----------------------------------------------------
# {'subject': ['Amazon', 'Amazon'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Raise', 'Control'], 'object': ['Prime Monthly Memberships', 'Amazon Prime'], 'object_type': ['PRODUCT', 'PRODUCT']}
# {'subject': ['Amazon', 'Amazon Prime', 'Amazon Prime'], 'subject_type': ['COMP', 'PRODUCT', 'PRODUCT'], 'relationship': ['Raise', 'Increase', 'Increase'], 'object': ['Prime Monthly Memberships', 'Monthly Fee', 'Monthly Fee'], 'object_type': ['PRODUCT', 'ECON_INDICATOR', 'ECON_INDICATOR']}
# {'subject': ['Amazon', 'Amazon', 'Amazon', 'Amazon', 'Prime Monthly Memberships', 'Prime Monthly Memberships', 'Prime Monthly Memberships', 'Amazon'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP', 'PRODUCT', 'PRODUCT', 'PRODUCT', 'COMP'], 'relationship': ['Raise', 'Raise', 'Has', 'Has', 'Has', 'Decrease', 'Operate_In'], 'object': ['Price', 'Prime Monthly Memberships', 'Price', 'Monthly Fee', '12.99', '10.99', 'U.S.'], 'object_type': ['CONCEPT', 'PRODUCT', 'CONCEPT', 'CONCEPT', 'CONCEPT', 'CONCEPT', 'GPE']}
# Doc #34:
# Total pairs:  41
# Total similarity count:  24.0
# Cosine similarity 'score':  58.53
# ----------------------------------------------------
# {'subject': ['Carnegie Hall', 'Carnegie Hall', 'David Crosby', 'Dance Theatre of Harlem', 'Kronos Quartet'], 'subject_type': ['ORG', 'ORG', 'PERSON', 'ORG', 'ORG'], 'relationship': ['Announce', 'Participates_In', 'Participates_In', 'Participates_In', 'Participates_In'], 'object': ["The '60s", "The '60s", "The '60s", "The '60s", "The '60s"], 'object_type': ['EVENT', 'EVENT', 'EVENT', 'EVENT', 'EVENT']}
# {'subject': ['Carnegie Hall', 'Carnegie Hall', 'The ’60s', 'David Crosby', 'Dance Theatre of Harlem', 'Kronos Quartet'], 'subject_type': ['ORG', 'ORG', 'EVENT', 'PERSON', 'ORG', 'ORG'], 'relationship': ['Operate_In', 'Introduce', 'Participates_In', 'Participates_In', 'Participates_In'], 'object': ['GPE', 'The ’60s', 'The ’60s', 'The ’60s', 'The ’60s'], 'object_type': ['SECTOR', 'EVENT', 'EVENT', 'EVENT', 'EVENT']}
# {'subject': ['Carnegie Hall', 'Carnegie Hall', 'Carnegie Hall', 'Carnegie Hall', 'Carnegie Hall'], 'subject_type': ['ORG', 'ORG', 'ORG', 'ORG', 'ORG'], 'relationship': ['Present', 'Has', 'Has', 'Has', 'Has'], 'object': ['The ’60s', 'series of concerts, lectures, films and dance and theatrical events', 'David Crosby', 'Dance Theatre of Harlem', 'Kronos Quartet'], 'object_type': ['EVENT', 'EVENT', 'PERSON', 'ORG', 'ORG']}
# Doc #35:
# Total pairs:  75
# Total similarity count:  37.1
# Cosine similarity 'score':  49.46
# ----------------------------------------------------
# {'subject': ['eHealth Inc', 'eHealth Inc'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Announce', 'Relate_To'], 'object': ['Preliminary Results', 'Fiscal Year 2017'], 'object_type': ['EVENT', 'EVENT']}
# {'subject': ['eHealth Inc', 'eHealth Inc', 'EHEALTH, INC.', 'EHEALTH, INC.', 'EHEALTH, INC.', 'EHEALTH, INC.', 'EHEALTH, INC.', 'THOMSON REUTERS I/B/E/S'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP', 'COMP', 'COMP', 'COMP', 'ORG'], 'relationship': ['Announce', 'Has', 'Has', 'Has', 'Has', 'Has', 'Has', 'Is_Member_Of'], 'object': ['preliminary results for the fourth quarter and fiscal year 2017', 'FY 2017 revenue', 'Q4 2017 revenue', 'GAAP net loss for Q4 2017', 'Q4 earnings per share', 'Q4 revenue view', 'Further company coverage', 'Further company coverage'], 'object_type': ['EVENT', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'CONCEPT', 'CONCEPT']}
# {'subject': ['eHealth Inc', 'eHealth Inc', 'eHealth Inc', 'eHealth Inc', 'Q4 2017', 'Q4 2017'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP', 'EVENT', 'EVENT'], 'relationship': ['Announce', 'Has', 'Has', 'Has', 'Has', 'Has'], 'object': ['Preliminary Results', 'FY 2017 Revenue', 'Q4 2017 Revenue', 'GAAP Net Loss', 'Earnings Per Share', 'Revenue'], 'object_type': ['EVENT', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR']}
# Doc #36:
# Total pairs:  76
# Total similarity count:  41.74
# Cosine similarity 'score':  54.92
# ----------------------------------------------------
# {'subject': ['Lockheed Martin Corp.', 'Lockheed Martin Corp.', 'Lockheed Martin Corp.'], 'subject_type': ['COMP', 'COMP', 'COMP'], 'relationship': ['Invests_In', 'Invests_In', 'Make'], 'object': ['Weapons Research', 'New Weapons and Training', '$5 Billion Payment to Pension Fund'], 'object_type': ['CONCEPT', 'CONCEPT', 'CONCEPT']}
# {'subject': ['U.S.', 'Lockheed Martin Corp.', 'Lockheed Martin Corp.'], 'subject_type': ['GPE', 'COMP', 'COMP'], 'relationship': ['Invests_In', 'Produce', 'Invests_In'], 'object': ['weapons research', 'new weapons and training', 'pension fund'], 'object_type': ['CONCEPT', 'PRODUCT', 'FIN_INSTRUMENT']}
# {'subject': ['U.S.', 'Defense Executives', 'Defense Executives', 'Defense Executives', 'Windfall from New Tax Rules', 'Lockheed Martin Corp.', 'Lockheed Martin Corp.', 'Lockheed Martin Corp.', 'Lockheed Martin Corp.'], 'subject_type': ['GPE', 'ORG', 'ORG', 'ORG', 'ECON_INDICATOR', 'COMP', 'COMP', 'COMP', 'COMP'], 'relationship': ['Has', 'Urge', 'Invest', 'In', 'Not', 'Expect', 'Pledge', 'Pledge', 'Make'], 'object': ['Defense Executives', 'Lawmakers and Federal Officials', 'Windfall from New Tax Rules', 'Weapons Research', 'Lower Prices for Pentagon', 'Tax Rate to Fall', 'Boost Investment', 'Boost Investment', '$5 Billion Payment'], 'object_type': ['ORG', 'ORG', 'ECON_INDICATOR', 'CONCEPT', 'ORGGOV', 'ECON_INDICATOR', 'CONCEPT', 'CONCEPT', 'FIN_INSTRUMENT']}
# ...
# Doc #288:
# Total pairs:  95
# Total similarity count:  49.14
# Cosine similarity 'score':  51.72
# ----------------------------------------------------
# {'subject': ['Primeline Energy Holdings', 'Primeline Energy Holdings'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Granted', 'Engaged_In'], 'object': ['Interim Injunction', 'Arbitration Proceedings'], 'object_type': ['EVENT', 'EVENT']}
# {'subject': ['Primeline Energy Holdings Inc', 'Primeline Energy Holdings Inc', 'Primeline Energy Holdings Inc'], 'subject_type': ['COMP', 'COMP', 'COMP'], 'relationship': ['Granted', 'Engage_In', 'Relate_To'], 'object': ['Interim Injunction', 'Arbitration Proceedings', 'China National Offshore Oil & CNOOC China Ltd'], 'object_type': ['EVENT', 'EVENT', 'ORG']}
# {'subject': ['Primeline Energy Holdings Inc', 'Primeline Energy Holdings Inc', 'Primeline Energy Holdings Inc', 'China National Offshore Oil & CNOOC China Ltd'], 'subject_type': ['COMP', 'COMP', 'COMP', 'ORG'], 'relationship': ['Has', 'Announce', 'Has', 'Relate_To'], 'object': ['Interim Injunction', 'Arbitration Proceedings', 'China National Offshore Oil & CNOOC China Ltd', 'Arbitration Proceedings'], 'object_type': ['CONCEPT', 'CONCEPT', 'ORG', 'CONCEPT']}
# Doc #289:
# Total pairs:  26
# Total similarity count:  15.62
# Cosine similarity 'score':  60.07
# ----------------------------------------------------
# {'subject': ['Fifth Third Bancorp', 'Fifth Third Bancorp', 'Fifth Third Bancorp', 'Fifth Third Bancorp'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP'], 'relationship': ['Announce', 'Announce', 'Announce', 'Announce'], 'object': ['Q1 NII', 'FY 2018 NII', 'Q1-2018 NIM', 'FY2018 NIM'], 'object_type': ['ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR']}
# {'subject': ['Fifth Third Bancorp', 'Fifth Third Bancorp', 'Fifth Third Bancorp', 'Fifth Third Bancorp'], 'subject_type': ['ORG', 'ORG', 'ORG', 'ORG'], 'relationship': ['Announce', 'Announce', 'Announce', 'Announce'], 'object': ['Q1 NII', 'FY 2018 NII', 'Q1-2018 NIM', 'FY2018 NIM'], 'object_type': ['ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR']}
# {'subject': ['Fifth Third Bancorp', 'Fifth Third Bancorp', 'Fifth Third Bancorp', 'Fifth Third Bancorp'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP'], 'relationship': ['Announce', 'Announce', 'Announce', 'Announce'], 'object': ['Q1 NII', 'FY 2018 NII', 'Q1-2018 NIM', 'FY2018 NIM'], 'object_type': ['ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR']}
# Doc #290:
# Total pairs:  48
# Total similarity count:  42.9
# Cosine similarity 'score':  89.37
# ----------------------------------------------------
# {'subject': ['U.S. Senate', 'Jerome Powell', 'Jerome Powell', 'Jerome Powell'], 'subject_type': ['ORGGOV', 'PERSON', 'PERSON', 'PERSON'], 'relationship': ['Announce', 'Is_Member_Of', 'Control', 'Relate_To'], 'object': ['Federal Reserve', 'Federal Reserve', 'Central Bank', 'Monetary Policy'], 'object_type': ['ORGREG', 'ORGREG', 'ORGREG', 'CONCEPT']}
# {'subject': ['U.S. Senate', 'Jerome Powell', 'Jerome Powell'], 'subject_type': ['ORGGOV', 'PERSON', 'PERSON'], 'relationship': ['Announce', 'Is_Member_Of', 'Relate_To'], 'object': ['Jerome Powell', 'Fed’s Board of Governors', 'Janet Yellen'], 'object_type': ['PERSON', 'ORGREG', 'PERSON']}
# {'subject': ['Federal Reserve', 'Governor Jerome Powell', 'Governor Jerome Powell', 'Views', 'Views', 'Background', 'Background', 'Governor Jerome Powell', 'Service', 'Service'], 'subject_type': ['ORGREG', 'PERSON', 'PERSON', 'CONCEPT', 'CONCEPT', 'CONCEPT', 'CONCEPT', 'PERSON', 'CONCEPT', 'CONCEPT'], 'relationship': ['Has', 'Is_Member_Of', 'Has', 'Align_With', 'Include', 'Include', 'Has', 'Has', 'On', 'Since'], 'object': ['Governor Jerome Powell', 'Federal Reserve', 'Views', 'Current Fed Chair Janet Yellen‘s', 'Lawyer', 'Former Investment Banker', 'Service', 'Fed’s Board of Governors', '2012', '2012'], 'object_type': ['PERSON', 'ORGREG', 'CONCEPT', 'PERSON', 'CONCEPT', 'CONCEPT', 'CONCEPT', 'ORGREG', 'DATE', 'DATE']}
# Doc #291:
# Total pairs:  82
# Total similarity count:  24.25
# Cosine similarity 'score':  29.57
# ----------------------------------------------------
# {'subject': ['Tsakos Energy Navigation', 'Tsakos Energy Navigation'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Announce', 'Produce'], 'object': ['Sale And Leaseback', 'Suezmax Tankers'], 'object_type': ['EVENT', 'PRODUCT']}
# {'subject': ['Tsakos Energy Navigation Ltd', 'Tsakos Energy Navigation Ltd'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Announce', 'Sale'], 'object': ['The Sale And Leaseback Of Two Suezmax Tankers', 'The Sale And Leaseback Of Two Suezmax Tankers'], 'object_type': ['EVENT', 'EVENT']}
# {'subject': ['Tsakos Energy Navigation Ltd', 'Tsakos Energy Navigation Ltd', 'Tsakos Energy Navigation Ltd', 'Tsakos Energy Navigation Ltd', 'Tsakos Energy Navigation Ltd'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP', 'COMP'], 'relationship': ['Announce', 'Has', 'Raise', 'Decrease', 'Add'], 'object': ['The Sale And Leaseback Of Two Suezmax Tankers', 'Two Suezmax Tankers', 'Sale Proceeds', 'Debt', '$16.0 Million', 'Cash', 'To Balance Sheet'], 'object_type': ['EVENT', 'PRODUCT', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'CONCEPT']}
# Doc #292:
# Total pairs:  24
# Total similarity count:  13.97
# Cosine similarity 'score':  58.2
# ----------------------------------------------------
# {'subject': ['Citigroup Inc', 'Citigroup Inc'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Announce', 'Announce'], 'object': ['Credit Card Charge-Offs', 'Credit Card Delinquency Rate'], 'object_type': ['ECON_INDICATOR', 'ECON_INDICATOR']}
# {'subject': ['Citigroup Inc', 'Citigroup Inc'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Announce', 'Announce'], 'object': ['Credit Card Charge-Offs', 'Credit Card Delinquency Rate'], 'object_type': ['FIN_INSTRUMENT', 'FIN_INSTRUMENT']}
# {'subject': ['Citigroup Inc', 'Citigroup Inc', 'Credit Card Charge-Offs', 'Credit Card Delinquency Rate'], 'subject_type': ['COMP', 'COMP', 'ECON_INDICATOR', 'ECON_INDICATOR'], 'relationship': ['Has', 'Has', 'Decrease', 'Decrease'], 'object': ['Credit Card Charge-Offs', 'Credit Card Delinquency Rate', '2.58 Percent', '1.53 Percent'], 'object_type': ['ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR', 'ECON_INDICATOR']}
# Doc #293:
# Total pairs:  20
# Total similarity count:  11.67
# Cosine similarity 'score':  58.35
# ----------------------------------------------------
# {'subject': ['Fortescue Metals Group Ltd', 'Fortescue Metals Group Ltd'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Produce', 'Decrease'], 'object': ['Iron Ore', 'Iron Ore Shipments', 'PRODUCT'], 'object_type': ['PRODUCT', 'PRODUCT']}
# {'subject': ['Fortescue Metals Group Ltd', 'Fortescue Metals Group Ltd'], 'subject_type': ['COMP', 'COMP'], 'relationship': ['Report', 'Produce'], 'object': ['4-percent decline in second-quarter iron ore shipments', 'iron ore'], 'object_type': ['ECON_INDICATOR', 'PRODUCT']}
# {'subject': ['Fortescue Metals Group Ltd', 'Fortescue Metals Group Ltd', 'Fortescue Metals Group Ltd', 'Fortescue Metals Group Ltd', '40.5 million tonnes', 'UBS'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP', 'ECON_INDICATOR', 'COMP'], 'relationship': ['Report', 'Has', 'Announce', 'Operate_In', 'Decrease', 'Forecast'], 'object': ['4-percent decline in second-quarter iron ore shipments', 'world’s fourth-largest producer of iron ore', 'shipments fell to 40.5 million tonnes', 'iron ore', '42.2 million tonnes', '40.5 million tonnes'], 'object_type': ['ECON_INDICATOR', 'CONCEPT', 'ECON_INDICATOR', 'PRODUCT', 'ECON_INDICATOR', 'ECON_INDICATOR']}
# Doc #294:
# Total pairs:  28
# Total similarity count:  17.9
# Cosine similarity 'score':  63.92
# ----------------------------------------------------
# {'subject': ['Russians', 'Russians'], 'subject_type': ['PERSON', 'PERSON'], 'relationship': ['Participates_In', 'Participates_In'], 'object': ['Orthodox Epiphany', 'Orthodox Epiphany'], 'object_type': ['EVENT', 'EVENT']}
# {'subject': ['Russians', 'Russians', 'Russians', 'Orthodox Epiphany'], 'subject_type': ['GPE', 'GPE', 'GPE', 'EVENT'], 'relationship': ['Participates_In', 'Participates_In', 'Participates_In', 'Is_Member_Of'], 'object': ['Orthodox Epiphany', 'Orthodox Epiphany', 'Orthodox Epiphany', 'Russians'], 'object_type': ['EVENT', 'EVENT', 'EVENT', 'GPE']}
# {'subject': ['Russians'], 'subject_type': ['GPE'], 'relationship': ['Participates_In'], 'object': ['Orthodox Epiphany'], 'object_type': ['EVENT']}
# Doc #295:
# Total pairs:  14
# Total similarity count:  13.99
# Cosine similarity 'score':  99.92
# ----------------------------------------------------
# {'subject': ['General Electric Co.', 'Securities and Exchange Commission', 'Securities and Exchange Commission'], 'subject_type': ['COMP', 'ORGREG', 'ORGREG'], 'relationship': ['Has', 'Investigate', 'Investigate'], 'object': ['Accounting Practices', 'General Electric Co.', 'Revenue Recognition'], 'object_type': ['CONCEPT', 'COMP', 'CONCEPT']}
# {'subject': ['General Electric Co.', 'Securities and Exchange Commission', 'General Electric Co.'], 'subject_type': ['COMP', 'ORGREG', 'COMP'], 'relationship': ['Announce', 'Investigate', 'Operate_In'], 'object': ['probe into the company’s accounting practices', 'GE’s recent review of its insurance business', 'struggling business'], 'object_type': ['EVENT', 'PRODUCT', 'SECTOR']}
# {'subject': ['General Electric Co.', 'General Electric Co.', 'Securities regulators', 'Securities and Exchange Commission', 'Securities and Exchange Commission', 'General Electric Co.', 'General Electric Co.'], 'subject_type': ['COMP', 'COMP', 'ORGREG', 'ORGREG', 'ORGREG', 'COMP', 'COMP'], 'relationship': ['Has', 'Announce', 'Operate_In', 'Impact', 'Introduce', 'Relate_To', 'Impact', 'Introduce', 'Relate_To'], 'object': ['probe', 'Securities regulators', 'Securities and Exchange Commission', 'General Electric Co.', 'recent review', 'insurance business', 'massive charges', 'revenue recognition', 'certain service contracts'], 'object_type': ['CONCEPT', 'ORGREG', 'ORGREG', 'COMP', 'CONCEPT', 'SECTOR', 'CONCEPT', 'CONCEPT', 'CONCEPT']}
# Doc #296:
# Total pairs:  51
# Total similarity count:  26.33
# Cosine similarity 'score':  51.62
# ----------------------------------------------------
# {'subject': ['Indian cabinet', 'Indian cabinet'], 'subject_type': ['ORGGOV', 'ORGGOV'], 'relationship': ['Announce', 'Ease'], 'object': ['FDI Proposal', 'FDI Rules for Aviation and Construction'], 'object_type': ['CONCEPT', 'CONCEPT']}
# {'subject': ['Indian cabinet', 'Indian cabinet', 'Indian cabinet'], 'subject_type': ['ORGGOV', 'ORGGOV', 'ORGGOV'], 'relationship': ['Announce', 'Control', 'Relate_To'], 'object': ['100 percent foreign direct investment', 'aviation sector', 'construction sector'], 'object_type': ['FIN_INSTRUMENT', 'SECTOR', 'SECTOR']}
# {'subject': ['Indian', 'Indian', 'Indian', 'Indian', 'Indian', 'Indian', 'Indian', 'Indian', 'proposal', 'proposal', 'proposal', 'cabinet', 'cabinet', 'cabinet', 'cabinet', 'cabinet', 'FDI rules', 'FDI rules'], 'subject_type': ['GPE', 'GPE', 'GPE', 'GPE', 'GPE', 'GPE', 'GPE', 'GPE', 'CONCEPT', 'CONCEPT', 'CONCEPT', 'ORG', 'ORG', 'ORG', 'ORG', 'ORG', 'CONCEPT', 'CONCEPT'], 'relationship': ['Has', 'Has', 'Has', 'Has', 'Allow', 'Allow', 'Allow', 'Clear', 'Allow', 'Allow', 'Allow', 'Clear', 'Allow', 'Allow', 'Allow', 'Ease', 'Ease', 'Ease'], 'object': ['cabinet', 'proposal', 'foreign direct investment', 'single-brand retail', '100 percent foreign direct investment', 'single-brand retail via automatic route', '100 percent foreign direct investment in single-brand retail via automatic route', 'proposal', '100 percent foreign direct investment', 'single-brand retail via automatic route', '100 percent foreign direct investment in single-brand retail via automatic route', 'proposal', '100 percent foreign direct investment', 'single-brand retail via automatic route', '100 percent foreign direct investment in single-brand retail via automatic route', 'FDI rules', 'FDI rules for the aviation and the construction sectors', 'aviation and the construction sectors'], 'object_type': ['ORG', 'CONCEPT', 'FIN_INSTRUMENT', 'SECTOR', 'FIN_INSTRUMENT', 'CONCEPT', 'CONCEPT', 'CONCEPT', 'FIN_INSTRUMENT', 'CONCEPT', 'CONCEPT', 'CONCEPT', 'FIN_INSTRUMENT', 'CONCEPT', 'CONCEPT', 'CONCEPT', 'CONCEPT', 'SECTOR']}
# Doc #297:
# Total pairs:  96
# Total similarity count:  48.12
# Cosine similarity 'score':  50.12
# ----------------------------------------------------
# {'subject': ['Electronic Arts', 'Electronic Arts', 'Electronic Arts', 'Star Wars Battlefront II'], 'subject_type': ['COMP', 'COMP', 'COMP', 'PRODUCT'], 'relationship': ['Operate_In', 'Produce', 'Announce', 'Negative_Impact_On'], 'object': ['Videogame Business', 'Star Wars Battlefront II', 'Microtransaction System', 'Electronic Arts', 'COMP'], 'object_type': ['SECTOR', 'PRODUCT', 'CONCEPT', 'COMP']}
# {'subject': ['Electronic Arts', 'Electronic Arts', 'EA', 'Star Wars Battlefront II', 'EA'], 'subject_type': ['COMP', 'COMP', 'COMP', 'PRODUCT', 'COMP'], 'relationship': ['Operate_In', 'Produce', 'Pull', 'Produce', 'Pull'], 'object': ['Videogame Business', 'Star Wars Battlefront II', 'Microtransaction System', 'Microtransaction System', 'Microtransaction System'], 'object_type': ['SECTOR', 'PRODUCT', 'PRODUCT', 'PRODUCT', 'PRODUCT']}
# {'subject': ['Electronic Arts', 'Electronic Arts', 'Star Wars Battlefront II', 'Electronic Arts'], 'subject_type': ['COMP', 'COMP', 'PRODUCT', 'COMP'], 'relationship': ['Operate_In', 'Produce', 'Has', 'Negative_Impact_On'], 'object': ['videogame business', 'Star Wars Battlefront II', 'microtransaction system', 'Star Wars Battlefront II'], 'object_type': ['SECTOR', 'PRODUCT', 'CONCEPT', 'PRODUCT']}
# Doc #298:
# Total pairs:  56
# Total similarity count:  32.04
# Cosine similarity 'score':  57.21
# ----------------------------------------------------
# {'subject': ['International Business Machines Corp.', 'International Business Machines Corp.', 'Ginni Rometty'], 'subject_type': ['COMP', 'COMP', 'PERSON'], 'relationship': ['Report', 'Signal', 'Control'], 'object': ['Higher Revenue', 'Continued Growth', 'International Business Machines Corp.'], 'object_type': ['ECON_INDICATOR', 'ECON_INDICATOR', 'COMP']}
# {'subject': ['International Business Machines Corp.', 'International Business Machines Corp.', 'Ginni Rometty'], 'subject_type': ['COMP', 'COMP', 'PERSON'], 'relationship': ['Report', 'Operate_In', 'Is_Member_Of'], 'object': ['Higher Revenue', 'Technology Sector', 'International Business Machines Corp.'], 'object_type': ['ECON_INDICATOR', 'SECTOR', 'COMP']}
# {'subject': ['International Business Machines Corp.', 'International Business Machines Corp.', 'International Business Machines Corp.', 'International Business Machines Corp.', 'International Business Machines Corp.', 'Ginni Rometty', 'Ginni Rometty'], 'subject_type': ['COMP', 'COMP', 'COMP', 'COMP', 'COMP', 'PERSON', 'PERSON'], 'relationship': ['Has', 'Has', 'Has', 'Operate_In', 'Positive_Impact_On', 'Tries', 'Is_Member_Of'], 'object': ['Chief Executive Ginni Rometty', '22.54 billion', '3.6%', 'Tech Giant', 'Ginni Rometty', 'Turn Around', 'International Business Machines Corp.'], 'object_type': ['PERSON', 'ECON_INDICATOR', 'ECON_INDICATOR', 'SECTOR', 'PERSON', 'CONCEPT', 'COMP']}
# Doc #299:
# Total pairs:  51
# Total similarity count:  25.9
# Cosine similarity 'score':  50.78
# ----------------------------------------------------
# Average similarity:  54.20693121609911

# %% [markdown]
# # Remaining Issues:
# - Redundant output pushes the score towards higher values without merit.
# - We are checking across entire outputs, instead of individual triplets.
#
# # Solution:
# - Remove high similarity pairs in each model's output.
# - Between models, remove highest similarity pairs both and only use those in the cosine similarity calculation.
#
#
#
# Look into company (appl, microsoft) stock market name and see how they compare to each other and to the company name.
#
# Look into sentence transformers: https://huggingface.co/spaces/mteb/leaderboard
